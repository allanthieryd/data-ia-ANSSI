# %%
import feedparser
url = "https://www.cert.ssi.gouv.fr/avis/feed/"
rss_feed = feedparser.parse(url)
for entry in rss_feed.entries:
  print("Titre :", entry.title)
  print("Description:", entry.description)
  print("Lien :", entry.link)
  print("Date :", entry.published)
# Out:
# Titre : Multiples vulnérabilités dans les produits Mattermost (22 mai 2026)
# Description: De multiples vulnérabilités ont été découvertes dans les produits Mattermost. Elles permettent à un attaquant de provoquer un problème de sécurité non spécifié par l'éditeur.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0632/
# Date : Fri, 22 May 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans FreeBSD (10 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans FreeBSD. Elles permettent à un attaquant de provoquer une élévation de privilèges.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0716/
# Date : Wed, 10 Jun 2026 00:00:00 +0000
# Titre : Vulnérabilité dans LibreNMS (11 juin 2026)
# Description: Une vulnérabilité a été découverte dans LibreNMS. Elle permet à un attaquant de provoquer une exécution de code arbitraire à distance.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0732/
# Date : Thu, 11 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans les produits NetApp (12 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans les produits NetApp. Elles permettent à un attaquant de provoquer un déni de service à distance, une atteinte à la confidentialité des données et une atteinte à l'intégrité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0742/
# Date : Fri, 12 Jun 2026 00:00:00 +0000
# Titre : Vulnérabilité dans les produits Moxa (12 juin 2026)
# Description: Une vulnérabilité a été découverte dans les produits Moxa. Elle permet à un attaquant de provoquer une atteinte à la confidentialité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0743/
# Date : Fri, 12 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans les produits Spring (12 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans les produits Spring. Elles permettent à un attaquant de provoquer un déni de service à distance et un problème de sécurité non spécifié par l'éditeur.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0744/
# Date : Fri, 12 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans le noyau Linux de SUSE (12 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans le noyau Linux de SUSE. Certaines d'entre elles permettent à un attaquant de provoquer une exécution de code arbitraire, une atteinte à la confidentialité des données et une atteinte à l'intégrité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0745/
# Date : Fri, 12 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans le noyau Linux d'Ubuntu (12 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans le noyau Linux d'Ubuntu. Certaines d'entre elles permettent à un attaquant de provoquer une exécution de code arbitraire, une élévation de privilèges et une atteinte à la confidentialité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0746/
# Date : Fri, 12 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans le noyau Linux de Red Hat (12 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans le noyau Linux de Red Hat. Certaines d'entre elles permettent à un attaquant de provoquer une exécution de code arbitraire à distance, une élévation de privilèges et un déni de service à distance.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0747/
# Date : Fri, 12 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans les produits IBM (12 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans les produits IBM. Certaines d'entre elles permettent à un attaquant de provoquer une exécution de code arbitraire à distance, un déni de service à distance et une atteinte à la confidentialité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0748/
# Date : Fri, 12 Jun 2026 00:00:00 +0000
# Titre : Vulnérabilité dans Oracle PeopleSoft (12 juin 2026)
# Description: Une vulnérabilité a été découverte dans Oracle PeopleSoft. Elle permet à un attaquant non authentifié de provoquer une exécution de code arbitraire à distance. Mandiant indique que la vulnérabilité CVE-2026-35273 est activement exploitée au moins depuis le 27 mai 2026.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0749/
# Date : Fri, 12 Jun 2026 00:00:00 +0000
# Titre : Vulnérabilité dans les produits HPE Aruba Networking (15 juin 2026)
# Description: Une vulnérabilité a été découverte dans les produits HPE Aruba Networking. Elle permet à un attaquant de provoquer une exécution de code arbitraire à distance et un déni de service à distance.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0750/
# Date : Mon, 15 Jun 2026 00:00:00 +0000
# Titre : Vulnérabilité dans Spring AI (15 juin 2026)
# Description: Une vulnérabilité a été découverte dans Spring AI. Elle permet à un attaquant de provoquer une injection SQL (SQLi) et un contournement de la politique de sécurité.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0751/
# Date : Mon, 15 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans les produits Mattermost (15 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans les produits Mattermost. Elles permettent à un attaquant de provoquer un problème de sécurité non spécifié par l'éditeur.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0752/
# Date : Mon, 15 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Microsoft Azure (15 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans Microsoft Azure. Elles permettent à un attaquant de provoquer un problème de sécurité non spécifié par l'éditeur.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0753/
# Date : Mon, 15 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Redmine (16 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans Redmine. Certaines d'entre elles permettent à un attaquant de provoquer une exécution de code arbitraire à distance, une atteinte à la confidentialité des données et une atteinte à l'intégrité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0754/
# Date : Tue, 16 Jun 2026 00:00:00 +0000
# Titre : Vulnérabilité dans LibreNMS (16 juin 2026)
# Description: Une vulnérabilité a été découverte dans LibreNMS. Elle permet à un attaquant de provoquer une injection de code indirecte à distance (XSS).
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0755/
# Date : Tue, 16 Jun 2026 00:00:00 +0000
# Titre : Vulnérabilité dans Cisco Catalyst (16 juin 2026)
# Description: Une vulnérabilité a été découverte dans Cisco Catalyst. Elle permet à un attaquant de provoquer une atteinte à l'intégrité des données. Cisco indique que la vulnérabilité CVE-2026-20262 est activement exploitée.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0756/
# Date : Tue, 16 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Microsoft Edge (16 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans Microsoft Edge. Elles permettent à un attaquant de provoquer un problème de sécurité non spécifié par l'éditeur.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0757/
# Date : Tue, 16 Jun 2026 00:00:00 +0000
# Titre : Vulnérabilité dans Microsoft Azure (16 juin 2026)
# Description: Une vulnérabilité a été découverte dans Microsoft Azure. Elle permet à un attaquant de provoquer un problème de sécurité non spécifié par l'éditeur.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0758/
# Date : Tue, 16 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans les produits Spring (16 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans les produits Spring. Elles permettent à un attaquant de provoquer une exécution de code arbitraire à distance et un problème de sécurité non spécifié par l'éditeur.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0759/
# Date : Tue, 16 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans les produits Moxa (16 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans les produits Moxa. Certaines d'entre elles permettent à un attaquant de provoquer une exécution de code arbitraire à distance, une atteinte à la confidentialité des données et un contournement de la politique de sécurité.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0760/
# Date : Tue, 16 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Google Chrome (17 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans Google Chrome. Elles permettent à un attaquant de provoquer un problème de sécurité non spécifié par l'éditeur.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0761/
# Date : Wed, 17 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans les produits Qnap (17 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans les produits Qnap. Certaines d'entre elles permettent à un attaquant de provoquer une exécution de code arbitraire à distance, une élévation de privilèges et un déni de service à distance.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0762/
# Date : Wed, 17 Jun 2026 00:00:00 +0000
# Titre : Vulnérabilité dans les produits Moxa (17 juin 2026)
# Description: Une vulnérabilité a été découverte dans les produits Moxa. Elle permet à un attaquant de provoquer un déni de service à distance et un contournement de la politique de sécurité.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0763/
# Date : Wed, 17 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans les produits Mozilla (17 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans les produits Mozilla. Certaines d'entre elles permettent à un attaquant de provoquer une exécution de code arbitraire à distance, une élévation de privilèges et un déni de service à distance.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0764/
# Date : Wed, 17 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Oracle MySQL (17 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans Oracle MySQL. Certaines d'entre elles permettent à un attaquant de provoquer une exécution de code arbitraire à distance, un déni de service à distance et une atteinte à la confidentialité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0765/
# Date : Wed, 17 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Oracle PeopleSoft (17 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans Oracle PeopleSoft. Elles permettent à un attaquant de provoquer une exécution de code arbitraire à distance, une atteinte à la confidentialité des données et une atteinte à l'intégrité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0766/
# Date : Wed, 17 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Oracle Systems (17 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans Oracle Systems. Elles permettent à un attaquant de provoquer un déni de service à distance, une atteinte à la confidentialité des données et une atteinte à l'intégrité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0767/
# Date : Wed, 17 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Oracle Virtualization (17 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans Oracle Virtualization. Certaines d'entre elles permettent à un attaquant de provoquer une exécution de code arbitraire à distance, un déni de service à distance et une atteinte à la confidentialité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0768/
# Date : Wed, 17 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Oracle Weblogic (17 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans Oracle Weblogic. Certaines d'entre elles permettent à un attaquant de provoquer une exécution de code arbitraire à distance, un déni de service à distance et une atteinte à la confidentialité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0769/
# Date : Wed, 17 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans les produits Mitel (18 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans les produits Mitel. Certaines d'entre elles permettent à un attaquant de provoquer une exécution de code arbitraire à distance, une atteinte à la confidentialité des données et une atteinte à l'intégrité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0770/
# Date : Thu, 18 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Drupal (18 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans Drupal. Certaines d'entre elles permettent à un attaquant de provoquer une exécution de code arbitraire à distance, une injection SQL (SQLi) et une falsification de requêtes côté serveur (SSRF).
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0771/
# Date : Thu, 18 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans les produits Cisco (18 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans les produits Cisco. Elles permettent à un attaquant de provoquer une exécution de code arbitraire à distance et une atteinte à la confidentialité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0772/
# Date : Thu, 18 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans les produits Atlassian (18 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans les produits Atlassian. Certaines d'entre elles permettent à un attaquant de provoquer une exécution de code arbitraire à distance, un déni de service à distance et une atteinte à la confidentialité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0773/
# Date : Thu, 18 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Splunk AI Toolkit (18 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans Splunk AI Toolkit. Elles permettent à un attaquant de provoquer une exécution de code arbitraire à distance et un contournement de la politique de sécurité.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0774/
# Date : Thu, 18 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Nginx (18 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans Nginx. Elles permettent à un attaquant de provoquer une exécution de code arbitraire à distance, un déni de service à distance et une atteinte à la confidentialité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0775/
# Date : Thu, 18 Jun 2026 00:00:00 +0000
# Titre : Vulnérabilité dans Synacor Zimbra Collaboration (18 juin 2026)
# Description: Une vulnérabilité a été découverte dans Synacor Zimbra Collaboration. Elle permet à un attaquant de provoquer un déni de service à distance.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0776/
# Date : Thu, 18 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Mattermost Desktop App (18 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans Mattermost Desktop App. Elles permettent à un attaquant de provoquer un problème de sécurité non spécifié par l'éditeur.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0777/
# Date : Thu, 18 Jun 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Google Android 17 (18 juin 2026)
# Description: De multiples vulnérabilités ont été découvertes dans Google Android 17. Certaines d'entre elles permettent à un attaquant de provoquer une exécution de code arbitraire à distance, une élévation de privilèges et un déni de service à distance.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0778/
# Date : Thu, 18 Jun 2026 00:00:00 +0000

# %%
import requests
import re
url = "https://www.cert.ssi.gouv.fr/alerte/CERTFR-2024-ALE-001/json/"
response = requests.get(url)
data = response.json()
#Extraction des CVE reference dans la clé cves du dict data
ref_cves=list(data["cves"])
#attention il s’agit d’une liste des dictionnaires avec name et url comme clés
print( "CVE référencés ", ref_cves)
# Extraction des CVE avec une regex
cve_pattern = r"CVE-\d{4}-\d{4,7}"
cve_list = list(set(re.findall(cve_pattern, str(data))))
print("CVE trouvés :", cve_list)
# Out:
# CVE référencés  [{'name': 'CVE-2023-46805', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-46805'}, {'name': 'CVE-2024-21887', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-21887'}, {'name': 'CVE-2024-21893', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-21893'}, {'name': 'CVE-2024-21888', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-21888'}, {'name': 'CVE-2024-22024', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-22024'}]
# CVE trouvés : ['CVE-2024-21887', 'CVE-2024-21893', 'CVE-2023-46805', 'CVE-2024-21888', 'CVE-2024-22024']

# %%
import requests

cve_id = "CVE-2023-24488"
url = f"https://cveawg.mitre.org/api/cve/{cve_id}"
response = requests.get(url)
data = response.json()
# Extraire la description
description = data["containers"]["cna"]["descriptions"][0]["value"]
# Extraire le score CVSS
#ATTENTION tous les CVE ne contiennent pas nécessairement ce champ, gérez l’exception,
#ou peut etre au lieu de cvssV3_0 c’est cvssV3_1 ou autre clé
cvss_score =data["containers"]["cna"]["metrics"][0]["cvssV3_1"]["baseScore"]
cwe = "Non disponible"
cwe_desc="Non disponible"
problemtype = data["containers"]["cna"].get("problemTypes", {})
if problemtype and "descriptions" in problemtype[0]:
  cwe = problemtype[0]["descriptions"][0].get("cweId", "Non disponible")
  cwe_desc=problemtype[0]["descriptions"][0].get("description", "Non disponible")
# Extraire les produits affectés
affected = data["containers"]["cna"]["affected"]
for product in affected:
  vendor = product["vendor"]
  product_name = product["product"]
  versions = [v["version"] for v in product["versions"] if v["status"] == "affected"]
  print(f"Éditeur : {vendor}, Produit : {product_name}, Versions : {', '.join(versions)}")
# Afficher les résultats
print(f"CVE : {cve_id}")
print(f"Description : {description}")
print(f"Score CVSS : {cvss_score}")
print(f"Type CWE : {cwe}")
print(f"CWE Description : {cwe_desc}")
# Out:
# Éditeur : Citrix, Produit : Citrix ADC and Citrix Gateway , Versions : 13.1, 13.0, 12.1, 12.1-FIPS , 13.1-FIPS , 12.1-NDcPP
# CVE : CVE-2023-24488
# Description : Cross site scripting vulnerability in Citrix ADC and Citrix Gateway  in allows and attacker to perform cross site scripting
# Score CVSS : 6.1
# Type CWE : CWE-79
# CWE Description : CWE-79 Improper Neutralization of Input During Web Page Generation ('Cross-site Scripting')

# %%
import os
import smtplib
from email.mime.text import MIMEText
from dotenv import load_dotenv

load_dotenv()

def send_email(to_email, subject, body):
  from_email = os.environ["EMAIL_SENDER"]
  password = os.environ["EMAIL_PASSWORD"]
  msg = MIMEText(body)
  msg['From'] = from_email
  msg['To'] = to_email
  msg['Subject'] = subject
  server = smtplib.SMTP('smtp.gmail.com', 587)
  server.starttls()
  server.login(from_email, password)
  server.sendmail(from_email, to_email, msg.as_string())
  server.quit()

send_email(os.environ["EMAIL_RECIPIENT"], "Alerte CVE critique", "Mettez à jour votre serveur Apache immédiatement.")
